# %%
import fenics as fe
import matplotlib.pyplot as plt
import numpy as np
import mshr

# %%
from ipywidgets import IntProgress
from IPython.display import display

def log_progress(sequence, every=10):
    progress = IntProgress(min=0, max=len(sequence), value=0)
    display(progress)

    for index, record in enumerate(sequence):
        
        if index % every == 0:
            progress.value = index
        yield record
    progress.value = len(sequence)

# %% [markdown]
# ### Domain

# %%
domain= mshr.Circle(fe.Point(1,0),2)
mesh = mshr.generate_mesh(domain,10)
fe.plot(mesh);

# %% [markdown]
# ### Boundaries

# %%
def boundary(x,x_boundary):    
    return x_boundary

bcs = fe.DirichletBC(space, f_bound, boundary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/stangerubuntu/Git-Fenics/Test/2D experimnt2.ipynb Cell 6' in <cell line: 4>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/stangerubuntu/Git-Fenics/Test/2D%20experimnt2.ipynb#ch0000005vscode-remote?line=0'>1</a> def boundary(x,x_boundary):
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/stangerubuntu/Git-Fenics/Test/2D%20experimnt2.ipynb#ch0000005vscode-remote?line=1'>2</a>     return x_boundary
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/stangerubuntu/Git-Fenics/Test/2D%20experimnt2.ipynb#ch0000005vscode-remote?line=3'>4</a> bcs = fe.DirichletBC(space, f_bound, boundary)
#
# NameError: name 'space' is not defined

# %% [markdown]
# ### Equations

# %%
de=fe.dx
Dot=fe.dot
Grad=fe.grad

# %%
eqB=
