# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x= np.linspace(-1,2,51)
y = x + np.random.random(51)*0.1

# %%
plt.figure(figsize=(10,10))
plt.plot(x,x,c='red')
plt.scatter(x,y)

# %%
plot_grid = plt.GridSpec(2,2)
figure=plt.figure(figsize=(10,10),facecolor='#DDD')

x=np.linspace(-2,5,101)
y = np.sinc(x)

axes_old= figure.add_subplot(plot_grid[0,:])
axes_old.plot(x,y)

# %%
def create_plot(matrix):
# Out:
#   Input In [5]
#
#     ^
# IndentationError: expected an indented block

# %%
type(axes_old)
# Out:
# matplotlib.axes._subplots.AxesSubplot
