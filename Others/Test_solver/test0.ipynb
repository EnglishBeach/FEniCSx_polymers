# %%
from FEnicS_base import *
import dolfinx
from dolfinx import mesh, fem, io, nls
from dolfinx.fem import VectorFunctionSpace
from mpi4py import MPI
import numpy as np
import ufl
import matplotlib.pyplot as plt

import jsonpickle as jp
import shutil
import re
import inspect
from tqdm import tqdm

# %%
domain = mesh.create_interval(nx=100, comm=MPI.COMM_WORLD, points=[0, 1])
# domain = mesh.create_unit_square(
#     MPI.COMM_WORLD,
#     10,
#     10,
#     cell_type=mesh.CellType.quadrilateral,
# )
space = FunctionSpace(domain, ('CG', 1))

x = SpatialCoordinate(space)[0]

set_connectivity(domain)

ds = Measure("ds", domain=domain)
norm = FacetNormal(domain)

u = TrialFunction(space)
v = TestFunction(space)

f = Constant(space, 2)

F = (grad(u)|dot|grad(v)) * dx - (f*v) * dx
# F -= (grad(u)|dot|norm) * v * ds

bcs = [
    DirichletBC(
        space=space,
        form=Constant(space, 2),
        combined_marker=lambda x: np.isclose(x[0], 0),
    ),
    # DirichletBC(
    #     space=space,
    #     form=Constant(space, 1),
    #     combined_marker=lambda x: np.isclose(x[0], 1),
    # )
]
problem = LinearProblem(
    L=rhs(F),
    a=lhs(F),
    bcs=bcs,
)

# %%
us = problem.solve()
us.x.array[:3]
# Out:
# array([2.    , 2.0199, 2.0396])

# %%
current_f = Function(space, us,'base')
# func_plot2D(*[Function(space, us,'base')])
func_plot1D([current_f])
# Out:
# <AxesSubplot:>

# %%
space2 = fem.VectorFunctionSpace(domain, ('CG', 1))
grad_f=Function(space2, grad(current_f))

# %%
print(
len(current_f.x.array),
len(grad_f.x.array),
sep='\n'
)
# Out:
# 101
# 101

# %%
space2.tabulate_dof_coordinates()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/Test/test0.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f46456e69435378227d/home/Test/test0.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> space2.tabulate_dof_coordinates()
#
# File /usr/local/dolfinx-real/lib/python3.10/dist-packages/dolfinx/fem/function.py:564, in FunctionSpace.tabulate_dof_coordinates(self)
#     563 def tabulate_dof_coordinates(self) -> np.ndarray:
# --> 564     return self._cpp_object.tabulate_dof_coordinates()
#
# RuntimeError: Cannot tabulate coordinates for a mixed FunctionSpace.

# %%
func_plot1D([grad_f])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/Test/test0.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f46456e69435378227d/home/Test/test0.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> func_plot1D([grad_f])
#
# File /home/Test/FEnicS_base.py:568, in func_plot1D(funcs, fig, ax, show_points)
#     566     fig.set_size_inches(16, 8)
#     567 for func in funcs:
# --> 568     x = func.function_space.tabulate_dof_coordinates()[:, 0]
#     569     y = func.x.array
#     570     cord = _np.array([x, y])
#
# File /usr/local/dolfinx-real/lib/python3.10/dist-packages/dolfinx/fem/function.py:564, in FunctionSpace.tabulate_dof_coordinates(self)
#     563 def tabulate_dof_coordinates(self) -> np.ndarray:
# --> 564     return self._cpp_object.tabulate_dof_coordinates()
#
# RuntimeError: Cannot tabulate coordinates for a mixed FunctionSpace.
